# %% [markdown]
# # Cryptocurrency Price Forecasting with ARIMA Model

# %% [markdown]
# **Description:** In this project, we aim to create a robust forecasting model for predicting the prices of a selected cryptocurrency. We will leverage the AutoRegressive Integrated Moving Average (ARIMA) model, a powerful time series analysis technique, to capture temporal patterns (recurring trends or behaviors that occur over time) in cryptocurrency price data.

# %% [markdown]
# # 1. Data Preprocessing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the Historical Data

# %%
data = pd.read_csv('BTCUSDT_15m.csv', parse_dates=['Date'], index_col='Date')
data
# Out:
#                          Open      High       Low     Close      Volume
# Date
# 2023-01-01 00:00:00  16541.77  16544.76  16520.00  16520.69  1172.53835
# 2023-01-01 00:15:00  16521.26  16545.70  16517.72  16544.19  1102.62888
# 2023-01-01 00:30:00  16544.19  16544.61  16508.39  16515.43  1365.65633
# 2023-01-01 00:45:00  16515.91  16536.84  16515.43  16529.67   724.01214
# 2023-01-01 01:00:00  16529.59  16541.80  16525.78  16538.21   977.24680
# ...                       ...       ...       ...       ...         ...
# 2023-06-30 22:45:00  30499.99  30500.00  30461.39  30476.68   119.16174
# 2023-06-30 23:00:00  30476.68  30476.99  30461.14  30467.73   100.13157
# 2023-06-30 23:15:00  30467.73  30513.39  30461.16  30508.74   207.29622
# 2023-06-30 23:30:00  30508.75  30544.44  30477.04  30513.45   273.88895
# 2023-06-30 23:45:00  30513.46  30513.46  30465.54  30472.00   179.27144
#
# [17371 rows x 5 columns]

# %% [markdown]
# ## Checking the data and missing values

# %%
type(data.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
data.dtypes
# Out:
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
## Lets try to check the general trend of the BTCUSDT prices
## its better to see general trend with daily data

data_daily = data.resample('1D').agg({
                                    'Open'   : 'first',
                                    'High'   : 'max',
                                    'Low'    : 'min',
                                    'Close'  : 'last',
                                    'Volume' : 'sum'
                                    })
data_daily.head()
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2023-01-01  16541.77  16628.00  16499.01  16616.75   96925.41374
# 2023-01-02  16617.17  16799.23  16548.70  16672.87  121888.57191
# 2023-01-03  16672.78  16778.40  16605.28  16675.18  159541.53733
# 2023-01-04  16675.65  16991.87  16652.66  16850.36  220362.18862
# 2023-01-05  16850.36  16879.82  16753.00  16831.85  163473.56641

# %%
# Create a trace for the candlestick chart
trace_candlestick = go.Candlestick(
    x=data_daily.index,
    open=data_daily['Open'],
    high=data_daily['High'],
    low=data_daily['Low'],
    close=data_daily['Close'],
    name='Candlestick'
)

# Create a trace for the trendline
trace_trendline = go.Scatter(
    x=[data_daily.index[0], data_daily.index[-1]],
    y=[data_daily['Open'].iloc[0], data_daily['Close'].iloc[-1]],
    mode='lines',
    line=dict(color='blue', width=2, dash='dash'),
    name='Trendline'
)

# Create the figure
fig = go.Figure(data=[trace_candlestick, trace_trendline])

# Set layout options
fig.update_layout(
    title='BTCUSDT Candlestick Chart with Trendline',
    xaxis_rangeslider_visible=False
)

# Show the plot
fig.show()

# %% [markdown]
# Although there are fluctuations in the price during the 6 months period, there is a clear upward trend in BTCUSDT prices. While the price is 16.500 USDT in the beginning of 2023, it eventually reached to 30.000 USDT at the end of June 2023.

# %% [markdown]
# # 2. Feature Engineering

# %% [markdown]
# # 3. Split Data into Training and Testing Sets

# %% [markdown]
# # 4. Model Selection

# %% [markdown]
# # 5. Model Training

# %% [markdown]
# # 6. Model Evaluation

# %% [markdown]
# # 7. Hyperparameter Tuning

# %% [markdown]
# # 8. Forecasting
